# %% [markdown]
# <a href="https://colab.research.google.com/github/matstabel/deep_learning/blob/main/ML_Exercise5_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning for BI 2
#
# ## Deep Learning exercises for week 6
#
# In this exercise, you will expand last weeks exercise by training pre-trained model

# %% [markdown]
# **About the CIFAR-10 dataset**
#
# The CIFAR-10 dataset is a widely-used dataset for benchmarking machine learning algorithms, especially in the field of image recognition. It consists of 60,000 32x32 color images in 10 different classes, with 6,000 images per class. The dataset is divided into 50,000 training images and 10,000 test images. The classes represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. Each image is labeled with one of these 10 classes, making it a standard dataset for evaluating algorithms for image classification tasks.
#
# The CIFAR-10 dataset was created by Alex Krizhevsky, Vinod Nair, and Geoffrey Hinton and is a subset of the 80 million tiny images dataset. Due to its moderate size and complexity, CIFAR-10 serves as an excellent benchmark for algorithms and techniques in computer vision, particularly for methodologies that are aimed at performing well on small to medium-sized datasets in image recognition tasks.

# %% [markdown]
# **Load and prepare the data**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# Load the CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Class names in the CIFAR-10 dataset
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step

# %% [markdown]
# **Plot images**
#
# Plot some images from the dataset.

# %%
import numpy as np

# Initialize a plot with 1 row and 10 columns
fig, axes = plt.subplots(2, 5, figsize=(14, 6))
axes = axes.ravel()

# Plot one image from each class
for i in range(10):
    # Find the index of the first image of each class
    index = np.where(train_labels.flatten() == i)[0][0]
    img = train_images[index]

    # Plot the image
    axes[i].imshow(img, cmap=plt.cm.binary)
    axes[i].set_title(class_names[i])
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
# Convert labels to one-hot encoding
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %% [markdown]
# **Model building**
#
# Build a convnet without adding data augmentation.

# %%
inputs = tf.keras.Input(shape=(32, 32, 3))  # Input layer

# Normalization layer
x = layers.Rescaling(1./255)(inputs)

# First Convolutional Block
x = layers.Conv2D(32, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)

# Second Convolutional Block
x = layers.Conv2D(64, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)

# Third Convolutional Block
x = layers.Conv2D(128, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)

# Flatten and Dense Layers
x = layers.Flatten()(x)
x = layers.Dense(64, activation='relu')(x)
outputs = layers.Dense(10, activation='softmax')(x)  # 10 classes in CIFAR-10

# Model creation
model = models.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 126,730 (495.04 KB)
#  Trainable params: 126,730 (495.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Compile and train the model**

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]

history = model.fit(train_images, train_labels, epochs=50,
                    validation_split=0.2, batch_size=256,
                    callbacks = callbacks)
# Out:
# Epoch 1/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.3253 - loss: 1.8408 - val_accuracy: 0.4131 - val_loss: 1.5882
# Epoch 2/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4607 - loss: 1.4832 - val_accuracy: 0.4983 - val_loss: 1.3940
# Epoch 3/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5250 - loss: 1.3292 - val_accuracy: 0.5198 - val_loss: 1.3282
# Epoch 4/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5641 - loss: 1.2330 - val_accuracy: 0.5715 - val_loss: 1.2092
# Epoch 5/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5899 - loss: 1.1689 - val_accuracy: 0.5533 - val_loss: 1.2867
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6088 - loss: 1.1145 - val_accuracy: 0.6050 - val_loss: 1.1367
# Epoch 7/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6263 - loss: 1.0674 - val_accuracy: 0.6041 - val_loss: 1.1300
# Epoch 8/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6423 - loss: 1.0202 - val_accuracy: 0.6258 - val_loss: 1.0709
# Epoch 9/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6579 - loss: 0.9814 - val_accuracy: 0.6440 - val_loss: 1.0179
# Epoch 10/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6703 - loss: 0.9460 - val_accuracy: 0.6338 - val_loss: 1.0588
# Epoch 11/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6787 - loss: 0.9198 - val_accuracy: 0.6472 - val_loss: 1.0176
# Epoch 12/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6838 - loss: 0.9014 - val_accuracy: 0.6401 - val_loss: 1.0613
# Epoch 13/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6977 - loss: 0.8683 - val_accuracy: 0.6436 - val_loss: 1.0377
# Epoch 14/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7046 - loss: 0.8450 - val_accuracy: 0.6620 - val_loss: 0.9845
# Epoch 15/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7158 - loss: 0.8208 - val_accuracy: 0.6672 - val_loss: 0.9865
# Epoch 16/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7257 - loss: 0.7910 - val_accuracy: 0.6611 - val_loss: 0.9926
# Epoch 17/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7322 - loss: 0.7716 - val_accuracy: 0.6863 - val_loss: 0.9214
# Epoch 18/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7419 - loss: 0.7507 - val_accuracy: 0.6743 - val_loss: 0.9725
# Epoch 19/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7463 - loss: 0.7386 - val_accuracy: 0.6851 - val_loss: 0.9176
# Epoch 20/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7536 - loss: 0.7119 - val_accuracy: 0.6822 - val_loss: 0.9650
# Epoch 21/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7608 - loss: 0.6940 - val_accuracy: 0.6800 - val_loss: 0.9521
# Epoch 22/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7679 - loss: 0.6723 - val_accuracy: 0.6956 - val_loss: 0.9267
# Epoch 23/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7750 - loss: 0.6554 - val_accuracy: 0.6973 - val_loss: 0.9040
# Epoch 24/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7808 - loss: 0.6368 - val_accuracy: 0.6882 - val_loss: 0.9377
# Epoch 25/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7841 - loss: 0.6235 - val_accuracy: 0.6903 - val_loss: 0.9319
# Epoch 26/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7933 - loss: 0.5997 - val_accuracy: 0.7023 - val_loss: 0.9128
# Epoch 27/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8024 - loss: 0.5741 - val_accuracy: 0.7071 - val_loss: 0.9071
# Epoch 28/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7980 - loss: 0.5832 - val_accuracy: 0.7066 - val_loss: 0.9265
# Epoch 29/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8109 - loss: 0.5499 - val_accuracy: 0.7027 - val_loss: 0.9354
# Epoch 30/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8120 - loss: 0.5442 - val_accuracy: 0.7065 - val_loss: 0.9191
# Epoch 31/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8238 - loss: 0.5154 - val_accuracy: 0.6956 - val_loss: 0.9853
# Epoch 32/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8225 - loss: 0.5093 - val_accuracy: 0.6836 - val_loss: 1.0113
# Epoch 33/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8299 - loss: 0.4959 - val_accuracy: 0.7043 - val_loss: 0.9414
# Epoch 34/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8325 - loss: 0.4826 - val_accuracy: 0.7037 - val_loss: 0.9505
# Epoch 35/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8371 - loss: 0.4722 - val_accuracy: 0.6987 - val_loss: 0.9929
# Epoch 36/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8453 - loss: 0.4506 - val_accuracy: 0.6900 - val_loss: 1.0188
# Epoch 37/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8482 - loss: 0.4374 - val_accuracy: 0.6997 - val_loss: 1.0115
# Epoch 38/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8566 - loss: 0.4189 - val_accuracy: 0.7037 - val_loss: 1.0043
# Epoch 39/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8620 - loss: 0.4008 - val_accuracy: 0.6937 - val_loss: 1.0613
# Epoch 40/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8685 - loss: 0.3831 - val_accuracy: 0.7017 - val_loss: 1.0531
# Epoch 41/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8696 - loss: 0.3765 - val_accuracy: 0.6957 - val_loss: 1.0789
# Epoch 42/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8756 - loss: 0.3642 - val_accuracy: 0.7027 - val_loss: 1.0581
# Epoch 43/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8803 - loss: 0.3482 - val_accuracy: 0.6884 - val_loss: 1.1644
# Epoch 44/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8823 - loss: 0.3419 - val_accuracy: 0.6930 - val_loss: 1.1461
# Epoch 45/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8834 - loss: 0.3352 - val_accuracy: 0.6897 - val_loss: 1.1621
# Epoch 46/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8931 - loss: 0.3124 - val_accuracy: 0.6950 - val_loss: 1.2042
# Epoch 47/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8948 - loss: 0.3039 - val_accuracy: 0.6973 - val_loss: 1.1866
# Epoch 48/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8939 - loss: 0.3045 - val_accuracy: 0.6917 - val_loss: 1.2410
# Epoch 49/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9031 - loss: 0.2861 - val_accuracy: 0.6940 - val_loss: 1.2237
# Epoch 50/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9109 - loss: 0.2642 - val_accuracy: 0.6979 - val_loss: 1.2443

# %% [markdown]
# **Plotting Training and Validation Loss and Accuracy**

# %%
# Assuming 'history' is the return value from model.fit()
history_dict = history.history

# Extracting loss and accuracy history
train_loss = history_dict['loss']
val_loss = history_dict['val_loss']
train_accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

epochs = range(1, len(train_loss) + 1)

# Plotting training and validation loss
plt.figure(figsize=(14, 5))

# Training and validation loss plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'bo-', label='Training Loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Training and validation accuracy plot
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()  # Adjusts the plots to ensure they don't overlap
plt.show()

# %% [markdown]
# **Test data evaluation**

# %%
best_model = keras.models.load_model("convnet_from_scratch.keras")

test_loss, test_acc = best_model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6942 - loss: 0.8987
# Test accuracy: 0.6941999793052673

# %% [markdown]
# ## Data augmentation addition
#
# Now, add a data augmentation step and compare model performance.

# %% [markdown]
# **Model building**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

inputs = keras.Input(shape=(32, 32, 3))

# Applying augmentation on the inputs
x = data_augmentation(inputs)

# Normalization layer
x = layers.Rescaling(1./255)(x)

# Convolutional blocks and rest of the model
x = layers.Conv2D(32, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(64, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(128, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Flatten()(x)
x = layers.Dense(64, activation='relu')(x)
outputs = layers.Dense(10, activation='softmax')(x)

# Create the model
model = keras.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_1 (Rescaling)         │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 126,730 (495.04 KB)
#  Trainable params: 126,730 (495.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Compile and train the model**

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="aug_convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]

history = model.fit(train_images, train_labels, epochs=100,
                    validation_split=0.2, batch_size=256,
                    callbacks = callbacks, verbose=0)

# %% [markdown]
# **Plotting Training and Validation Loss and Accuracy**

# %%
# Assuming 'history' is the return value from model.fit()
history_dict = history.history

# Extracting loss and accuracy history
train_loss = history_dict['loss']
val_loss = history_dict['val_loss']
train_accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

epochs = range(1, len(train_loss) + 1)

# Plotting training and validation loss
plt.figure(figsize=(14, 5))

# Training and validation loss plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'bo-', label='Training Loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Training and validation accuracy plot
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()  # Adjusts the plots to ensure they don't overlap
plt.show()

# %%
def print_best_val_loss_and_accuracy(history):
    history_dict = history.history

    # Find the index of the best validation loss
    best_val_loss_index = np.argmin(history_dict['val_loss'])

    # Retrieve the best validation loss
    best_val_loss = history_dict['val_loss'][best_val_loss_index]

    # Retrieve the validation accuracy corresponding to the best validation loss
    best_val_accuracy = history_dict['val_accuracy'][best_val_loss_index]

    print(f"Best Validation Loss: {best_val_loss}")
    print(f"Validation Accuracy at Best Loss: {best_val_accuracy}")

# %%
print_best_val_loss_and_accuracy(history)
# Out:
# Best Validation Loss: 0.7875093817710876
# Validation Accuracy at Best Loss: 0.7366999983787537

# %%
best_model = keras.models.load_model("aug_convnet_from_scratch.keras")

test_loss, test_acc = best_model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7366 - loss: 0.7760
# Test accuracy: 0.7365999817848206

# %% [markdown]
# ## Experiment with more data augmentation
# Try experimenting with adding more data augmentation techniques

# %%
# Enhanced data augmentation
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal", input_shape=(32, 32, 3)),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
        layers.RandomContrast(0.1),  # Adjusts the contrast
        layers.RandomTranslation(height_factor=0.1, width_factor=0.1),  # Translates the image
        # Potentially add more augmentation techniques here
    ]
)

inputs = keras.Input(shape=(32, 32, 3))

# Applying enhanced augmentation on the inputs
x = data_augmentation(inputs)

# Continue with normalization and the rest of your model
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(32, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(64, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(128, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Flatten()(x)
x = layers.Dense(64, activation='relu')(x)
outputs = layers.Dense(10, activation='softmax')(x)

# Create the model
model = keras.Model(inputs=inputs, outputs=outputs)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/preprocessing/data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="more_aug_convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]

history = model.fit(train_images, train_labels, epochs=100,
                    validation_split=0.2, batch_size=256,
                    callbacks = callbacks)
# Out:
# Epoch 1/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.2837 - loss: 1.9416 - val_accuracy: 0.3813 - val_loss: 1.6751
# Epoch 2/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4002 - loss: 1.6593 - val_accuracy: 0.4530 - val_loss: 1.5153
# Epoch 3/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.4323 - loss: 1.5684 - val_accuracy: 0.4890 - val_loss: 1.4323
# Epoch 4/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4574 - loss: 1.4976 - val_accuracy: 0.5133 - val_loss: 1.3872
# Epoch 5/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4794 - loss: 1.4484 - val_accuracy: 0.4492 - val_loss: 1.5957
# Epoch 6/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.4956 - loss: 1.4076 - val_accuracy: 0.5118 - val_loss: 1.4208
# Epoch 7/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5099 - loss: 1.3741 - val_accuracy: 0.5544 - val_loss: 1.2829
# Epoch 8/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5224 - loss: 1.3426 - val_accuracy: 0.5606 - val_loss: 1.2822
# Epoch 9/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5318 - loss: 1.3179 - val_accuracy: 0.5427 - val_loss: 1.3497
# Epoch 10/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5419 - loss: 1.2906 - val_accuracy: 0.5669 - val_loss: 1.2691
# Epoch 11/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5451 - loss: 1.2751 - val_accuracy: 0.5613 - val_loss: 1.2778
# Epoch 12/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5556 - loss: 1.2554 - val_accuracy: 0.5798 - val_loss: 1.1976
# Epoch 13/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5604 - loss: 1.2469 - val_accuracy: 0.5931 - val_loss: 1.1239
# Epoch 14/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5677 - loss: 1.2176 - val_accuracy: 0.6280 - val_loss: 1.0621
# Epoch 15/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5742 - loss: 1.1948 - val_accuracy: 0.6075 - val_loss: 1.1320
# Epoch 16/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5795 - loss: 1.1869 - val_accuracy: 0.6216 - val_loss: 1.0837
# Epoch 17/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5877 - loss: 1.1717 - val_accuracy: 0.6409 - val_loss: 1.0328
# Epoch 18/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.5928 - loss: 1.1590 - val_accuracy: 0.6114 - val_loss: 1.1383
# Epoch 19/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5958 - loss: 1.1472 - val_accuracy: 0.6323 - val_loss: 1.0550
# Epoch 20/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5997 - loss: 1.1353 - val_accuracy: 0.5955 - val_loss: 1.2040
# Epoch 21/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6040 - loss: 1.1249 - val_accuracy: 0.6575 - val_loss: 0.9991
# Epoch 22/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6086 - loss: 1.1136 - val_accuracy: 0.6630 - val_loss: 0.9786
# Epoch 23/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6109 - loss: 1.1079 - val_accuracy: 0.6233 - val_loss: 1.1099
# Epoch 24/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6144 - loss: 1.0920 - val_accuracy: 0.6259 - val_loss: 1.1158
# Epoch 25/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6163 - loss: 1.0926 - val_accuracy: 0.6356 - val_loss: 1.0644
# Epoch 26/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6209 - loss: 1.0767 - val_accuracy: 0.6489 - val_loss: 1.0258
# Epoch 27/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6283 - loss: 1.0597 - val_accuracy: 0.6403 - val_loss: 1.0645
# Epoch 28/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6231 - loss: 1.0687 - val_accuracy: 0.6557 - val_loss: 0.9900
# Epoch 29/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6314 - loss: 1.0559 - val_accuracy: 0.6497 - val_loss: 1.0182
# Epoch 30/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6327 - loss: 1.0448 - val_accuracy: 0.6558 - val_loss: 1.0117
# Epoch 31/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6340 - loss: 1.0407 - val_accuracy: 0.6730 - val_loss: 0.9569
# Epoch 32/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6417 - loss: 1.0303 - val_accuracy: 0.6617 - val_loss: 0.9970
# Epoch 33/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6396 - loss: 1.0361 - val_accuracy: 0.6770 - val_loss: 0.9540
# Epoch 34/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6424 - loss: 1.0180 - val_accuracy: 0.6482 - val_loss: 1.0440
# Epoch 35/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6442 - loss: 1.0126 - val_accuracy: 0.6486 - val_loss: 1.0382
# Epoch 36/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6453 - loss: 1.0119 - val_accuracy: 0.6535 - val_loss: 1.0329
# Epoch 37/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6492 - loss: 1.0025 - val_accuracy: 0.6937 - val_loss: 0.8934
# Epoch 38/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6520 - loss: 0.9972 - val_accuracy: 0.6801 - val_loss: 0.9331
# Epoch 39/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6561 - loss: 0.9850 - val_accuracy: 0.6874 - val_loss: 0.9183
# Epoch 40/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6543 - loss: 0.9858 - val_accuracy: 0.6639 - val_loss: 1.0141
# Epoch 41/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6561 - loss: 0.9775 - val_accuracy: 0.6850 - val_loss: 0.9271
# Epoch 42/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6583 - loss: 0.9742 - val_accuracy: 0.6714 - val_loss: 0.9538
# Epoch 43/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6610 - loss: 0.9684 - val_accuracy: 0.6675 - val_loss: 1.0027
# Epoch 44/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6615 - loss: 0.9659 - val_accuracy: 0.6698 - val_loss: 0.9986
# Epoch 45/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6620 - loss: 0.9671 - val_accuracy: 0.6878 - val_loss: 0.9007
# Epoch 46/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6644 - loss: 0.9539 - val_accuracy: 0.6848 - val_loss: 0.9475
# Epoch 47/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6641 - loss: 0.9546 - val_accuracy: 0.6908 - val_loss: 0.9017
# Epoch 48/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6694 - loss: 0.9459 - val_accuracy: 0.6741 - val_loss: 0.9675
# Epoch 49/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6682 - loss: 0.9463 - val_accuracy: 0.7053 - val_loss: 0.8582
# Epoch 50/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6709 - loss: 0.9402 - val_accuracy: 0.7015 - val_loss: 0.8652
# Epoch 51/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6707 - loss: 0.9386 - val_accuracy: 0.6810 - val_loss: 0.9573
# Epoch 52/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6730 - loss: 0.9301 - val_accuracy: 0.7050 - val_loss: 0.8720
# Epoch 53/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6758 - loss: 0.9259 - val_accuracy: 0.6976 - val_loss: 0.8878
# Epoch 54/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6769 - loss: 0.9248 - val_accuracy: 0.6865 - val_loss: 0.9388
# Epoch 55/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6793 - loss: 0.9166 - val_accuracy: 0.6823 - val_loss: 0.9602
# Epoch 56/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.6789 - loss: 0.9160 - val_accuracy: 0.6832 - val_loss: 0.9275
# Epoch 57/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6812 - loss: 0.9134 - val_accuracy: 0.6981 - val_loss: 0.9043
# Epoch 58/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6800 - loss: 0.9148 - val_accuracy: 0.7046 - val_loss: 0.8682
# Epoch 59/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6803 - loss: 0.9156 - val_accuracy: 0.6921 - val_loss: 0.9069
# Epoch 60/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6841 - loss: 0.8993 - val_accuracy: 0.7158 - val_loss: 0.8372
# Epoch 61/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6822 - loss: 0.9079 - val_accuracy: 0.7022 - val_loss: 0.8837
# Epoch 62/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6865 - loss: 0.8992 - val_accuracy: 0.6965 - val_loss: 0.8959
# Epoch 63/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6884 - loss: 0.8943 - val_accuracy: 0.6963 - val_loss: 0.8904
# Epoch 64/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6876 - loss: 0.8926 - val_accuracy: 0.6882 - val_loss: 0.9228
# Epoch 65/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6896 - loss: 0.8852 - val_accuracy: 0.7120 - val_loss: 0.8287
# Epoch 66/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6880 - loss: 0.8861 - val_accuracy: 0.7062 - val_loss: 0.8780
# Epoch 67/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6909 - loss: 0.8830 - val_accuracy: 0.7150 - val_loss: 0.8409
# Epoch 68/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.6991 - loss: 0.8654 - val_accuracy: 0.7198 - val_loss: 0.8292
# Epoch 69/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6943 - loss: 0.8715 - val_accuracy: 0.7188 - val_loss: 0.8387
# Epoch 70/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6969 - loss: 0.8675 - val_accuracy: 0.7143 - val_loss: 0.8420
# Epoch 71/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6951 - loss: 0.8663 - val_accuracy: 0.7238 - val_loss: 0.7995
# Epoch 72/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6931 - loss: 0.8706 - val_accuracy: 0.7223 - val_loss: 0.8108
# Epoch 73/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.6986 - loss: 0.8616 - val_accuracy: 0.6902 - val_loss: 0.9260
# Epoch 74/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.6992 - loss: 0.8592 - val_accuracy: 0.7177 - val_loss: 0.8222
# Epoch 75/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6990 - loss: 0.8590 - val_accuracy: 0.7110 - val_loss: 0.8517
# Epoch 76/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7025 - loss: 0.8542 - val_accuracy: 0.7083 - val_loss: 0.8681
# Epoch 77/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6993 - loss: 0.8520 - val_accuracy: 0.7180 - val_loss: 0.8173
# Epoch 78/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7003 - loss: 0.8555 - val_accuracy: 0.7126 - val_loss: 0.8777
# Epoch 79/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7005 - loss: 0.8527 - val_accuracy: 0.7232 - val_loss: 0.8106
# Epoch 80/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7052 - loss: 0.8402 - val_accuracy: 0.7196 - val_loss: 0.8099
# Epoch 81/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7055 - loss: 0.8421 - val_accuracy: 0.6997 - val_loss: 0.8829
# Epoch 82/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7051 - loss: 0.8407 - val_accuracy: 0.7167 - val_loss: 0.8350
# Epoch 83/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7057 - loss: 0.8390 - val_accuracy: 0.7138 - val_loss: 0.8372
# Epoch 84/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7071 - loss: 0.8368 - val_accuracy: 0.7213 - val_loss: 0.8199
# Epoch 85/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7030 - loss: 0.8431 - val_accuracy: 0.7232 - val_loss: 0.8101
# Epoch 86/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7072 - loss: 0.8346 - val_accuracy: 0.7097 - val_loss: 0.8563
# Epoch 87/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7101 - loss: 0.8302 - val_accuracy: 0.7035 - val_loss: 0.8777
# Epoch 88/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7090 - loss: 0.8327 - val_accuracy: 0.7150 - val_loss: 0.8418
# Epoch 89/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7109 - loss: 0.8278 - val_accuracy: 0.7178 - val_loss: 0.8115
# Epoch 90/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7093 - loss: 0.8240 - val_accuracy: 0.7061 - val_loss: 0.8747
# Epoch 91/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7129 - loss: 0.8208 - val_accuracy: 0.7232 - val_loss: 0.8175
# Epoch 92/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7125 - loss: 0.8241 - val_accuracy: 0.7140 - val_loss: 0.8432
# Epoch 93/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7146 - loss: 0.8136 - val_accuracy: 0.7240 - val_loss: 0.7904
# Epoch 94/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7166 - loss: 0.8147 - val_accuracy: 0.7371 - val_loss: 0.7672
# Epoch 95/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7111 - loss: 0.8200 - val_accuracy: 0.7292 - val_loss: 0.8014
# Epoch 96/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7154 - loss: 0.8155 - val_accuracy: 0.7181 - val_loss: 0.8193
# Epoch 97/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7179 - loss: 0.8091 - val_accuracy: 0.7052 - val_loss: 0.8896
# Epoch 98/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7160 - loss: 0.8112 - val_accuracy: 0.7324 - val_loss: 0.7987
# Epoch 99/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7142 - loss: 0.8123 - val_accuracy: 0.7230 - val_loss: 0.8182
# Epoch 100/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7173 - loss: 0.8083 - val_accuracy: 0.7030 - val_loss: 0.8882

# %%
# Assuming 'history' is the return value from model.fit()
history_dict = history.history

# Extracting loss and accuracy history
train_loss = history_dict['loss']
val_loss = history_dict['val_loss']
train_accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

epochs = range(1, len(train_loss) + 1)

# Plotting training and validation loss
plt.figure(figsize=(14, 5))

# Training and validation loss plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'bo-', label='Training Loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Training and validation accuracy plot
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()  # Adjusts the plots to ensure they don't overlap
plt.show()

# %%
print_best_val_loss_and_accuracy(history)
# Out:
# Best Validation Loss: 0.7672255039215088
# Validation Accuracy at Best Loss: 0.7371000051498413

# %%
best_model = keras.models.load_model("more_aug_convnet_from_scratch.keras")

test_loss, test_acc = best_model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7328 - loss: 0.7865
# Test accuracy: 0.7328000068664551

# %% [markdown]
# ## What's next?
#
# To further increase the performance of our model, we could make some tweaks here and there, like icreasing the number of filters in the convolutional layers can help the model learn more complex features. Similarly, adjusting the number of neurons in the dense layers might improve learning capacity.
#
# However, at this stage, gains from such changes are likely going to marginal.
#
# Instead, there are two things that would likely boost performance:
#
# 1) More and better data! The data is greatly pixilated. Higher resolution data would allow us to build deeper models that generalize better.
#
# 2) More and better tricks! Next in next sessions, we'll learn about advanced computer vision techniques that can push performance even further.
